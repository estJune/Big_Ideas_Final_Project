# %%
import pandas as pd
import geopandas
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

df = pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
df = df.dropna()


#null = df['neighborhood'].value_counts().sort_values(ascending=True)


#df["neighborhood"].value_counts().sort_index().plot.pie(y="neighborhood", subplots=False, figsize=(30,30))

#plt.style.use('seaborn')
#nbh.plot.bar(figsize=(25,25), ylim=[0,100])
#plt.title("Number of Fires in Pittsburgh Neighborhoods")
#plt.xlabel("Neighborhoods")
#plt.ylabel("Number of Fires")
# Out:
# neighborhood
# Carrick                      252
# Squirrel Hill South          222
# Central Business District    220
# South Side Flats             217
# Hazelwood                    213
#                             ...
# St. Clair                     11
# Ridgemont                     10
# East Carnegie                 10
# Mt. Oliver                    10
# Regent Square                  5
# Name: number_of_fires, Length: 90, dtype: int64

# %%
import pandas as pd
import geopandas
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

df = pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
df = df.dropna()

count = 1

df["number_of_fires"] = count

num_fires = df.groupby("neighborhood").sum()['number_of_fires']
num_fires.sort_values(ascending=False)

neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")
#neighborhoods.plot()

fire_map = neighborhoods.merge(num_fires, how='left', left_on='hood',right_on='neighborhood')
#fire_map[['hood','number_of_fires','geometry']].head()
fire_map.plot(column='number_of_fires', cmap='OrRd', edgecolor="black", legend=True, legend_kwds = {'label': "Number of Fires"}, figsize=(15,15))
